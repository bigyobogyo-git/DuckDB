# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('NCD_RisC_Nature_2020_Cholesterol_age_specific_countries.csv').reset_index(drop = True)
#df

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Sex', 'Age group',
#        'Mean total cholesterol (mmol/L)',
#        'Mean total cholesterol lower 95% uncertainty interval (mmol/L)',
#        'Mean total cholesterol upper 95% uncertainty interval (mmol/L)',
#        'Mean non-HDL cholesterol (mmol/L)',
#        'Mean non-HDL cholesterol lower 95% uncertainty interval (mmol/L)',
#        'Mean non-HDL cholesterol upper 95% uncertainty interval (mmol/L)',
#        'Mean HDL cholesterol (mmol/L)',
#        'Mean HDL cholesterol lower 95% uncertainty interval (mmol/L)',
#        'Mean HDL cholesterol upper 95% uncertainty interval (mmol/L)'],
#       dtype='object')

# %%
df.rename(columns = {'Sex' : 'Gender',
                     'Age group' : 'Age_group',
                     'Mean total cholesterol (mmol/L)' : 'Mean_total_cholesterol_mmolL',
                     'Mean total cholesterol lower 95% uncertainty interval (mmol/L)' :
                     'Mean_total_cholesterol_lower_95_percent_uncertainty_interval_mmolL',
                     'Mean total cholesterol upper 95% uncertainty interval (mmol/L)' :
                     'Mean_total_cholesterol_upper_95_percent_uncertainty_interval_mmolL',
                     'Mean non-HDL cholesterol (mmol/L)' : 'Mean_non_HDL_cholesterol_mmolL',
                     'Mean non-HDL cholesterol lower 95% uncertainty interval (mmol/L)' :
                     'Mean_non_HDL_cholesterol_lower_95_percent_uncertainty_interval_mmolL',
                     'Mean non-HDL cholesterol upper 95% uncertainty interval (mmol/L)' :
                     'Mean_non_HDL_cholesterol_upper_95_percent_uncertainty_interval_mmolL',
                     'Mean HDL cholesterol (mmol/L)' : 'Mean_HDL_cholesterol_mmolL',
                     'Mean HDL cholesterol lower 95% uncertainty interval (mmol/L)' :
                     'Mean_HDL_cholesterol_lower_95_percent_uncertainty_interval_mmolL',
                     'Mean HDL cholesterol upper 95% uncertainty interval (mmol/L)' :
                     'Mean_HDL_cholesterol_upper_95_percent_uncertainty_interval_mmolL'}, inplace = True)

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Gender', 'Age_group',
#        'Mean_total_cholesterol_mmolL',
#        'Mean_total_cholesterol_lower_95_percent_uncertainty_interval_mmolL',
#        'Mean_total_cholesterol_upper_95_percent_uncertainty_interval_mmolL',
#        'Mean_non_HDL_cholesterol_mmolL',
#        'Mean_non_HDL_cholesterol_lower_95_percent_uncertainty_interval_mmolL',
#        'Mean_non_HDL_cholesterol_upper_95_percent_uncertainty_interval_mmolL',
#        'Mean_HDL_cholesterol_mmolL',
#        'Mean_HDL_cholesterol_lower_95_percent_uncertainty_interval_mmolL',
#        'Mean_HDL_cholesterol_upper_95_percent_uncertainty_interval_mmolL'],
#       dtype='object')

# %%
df
# Out:
#             Country  Year Gender Age_group  Mean_total_cholesterol_mmolL  \
# 0       Afghanistan  1980    Men     18-19                      3.938280
# 1       Afghanistan  1980    Men     20-24                      4.030348
# 2       Afghanistan  1980    Men     25-29                      4.152129
# 3       Afghanistan  1980    Men     30-34                      4.257240
# 4       Afghanistan  1980    Men     35-39                      4.339896
# ...             ...   ...    ...       ...                           ...
# 233995     Zimbabwe  2018  Women     65-69                      4.446930
# 233996     Zimbabwe  2018  Women     70-74                      4.372726
# 233997     Zimbabwe  2018  Women     75-79                      4.318492
# 233998     Zimbabwe  2018  Women     80-84                      4.324823
# 233999     Zimbabwe  2018  Women    85plus                      4.486063
#
#         Mean_total_cholesterol_lower_95_percent_uncertainty_interval_mmolL  \
# ...

# %%
df.to_csv('NCD_RisC_Nature_2020_Cholesterol_age_specific_countries_sql.csv', index=False, header=True)

# %%
df1 = pd.read_csv('NCD_RisC_Nature_2020_Cholesterol_age_specific_countries_sql.csv').reset_index(drop = True)
df1
# Out:
#             Country  Year Gender Age_group  Mean_total_cholesterol_mmolL  \
# 0       Afghanistan  1980    Men     18-19                      3.938280
# 1       Afghanistan  1980    Men     20-24                      4.030348
# 2       Afghanistan  1980    Men     25-29                      4.152129
# 3       Afghanistan  1980    Men     30-34                      4.257240
# 4       Afghanistan  1980    Men     35-39                      4.339896
# ...             ...   ...    ...       ...                           ...
# 233995     Zimbabwe  2018  Women     65-69                      4.446930
# 233996     Zimbabwe  2018  Women     70-74                      4.372726
# 233997     Zimbabwe  2018  Women     75-79                      4.318492
# 233998     Zimbabwe  2018  Women     80-84                      4.324823
# 233999     Zimbabwe  2018  Women    85plus                      4.486063
#
#         Mean_total_cholesterol_lower_95_percent_uncertainty_interval_mmolL  \
# ...

# %%
df1.columns
# Out:
# Index(['Country', 'Year', 'Gender', 'Age_group',
#        'Mean_total_cholesterol_mmolL',
#        'Mean_total_cholesterol_lower_95_percent_uncertainty_interval_mmolL',
#        'Mean_total_cholesterol_upper_95_percent_uncertainty_interval_mmolL',
#        'Mean_non_HDL_cholesterol_mmolL',
#        'Mean_non_HDL_cholesterol_lower_95_percent_uncertainty_interval_mmolL',
#        'Mean_non_HDL_cholesterol_upper_95_percent_uncertainty_interval_mmolL',
#        'Mean_HDL_cholesterol_mmolL',
#        'Mean_HDL_cholesterol_lower_95_percent_uncertainty_interval_mmolL',
#        'Mean_HDL_cholesterol_upper_95_percent_uncertainty_interval_mmolL'],
#       dtype='object')
